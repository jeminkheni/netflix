# %%
import pandas as pd
data=pd.read_csv("C:/Users/jemin kheni/Desktop/durvasa/jeminnn/netflix_titles.csv")
data.head
# Out:
# <bound method NDFrame.head of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
import sweetviz as sv
report = sv.analyze(data)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
cols=['show_id','date_added','description']
data=data.drop(cols,axis=1)
data
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show          Blood & Water              NaN
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans              NaN
# 4     TV Show           Kota Factory              NaN
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb              NaN
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
data.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# release_year       0
# rating             4
# duration           3
# listed_in          0
# dtype: int64

# %%
new_data = data.dropna(axis = 0, how ='any')

# %%
new_data.shape
new_data
# Out:
#          type                          title             director  \
# 7       Movie                        Sankofa         Haile Gerima
# 8     TV Show  The Great British Baking Show      Andy Devonshire
# 9       Movie                   The Starling       Theodore Melfi
# 12      Movie                   Je Suis Karl  Christian Schwochow
# 24      Movie                          Jeans           S. Shankar
# ...       ...                            ...                  ...
# 8801    Movie                        Zinzana      Majid Al Ansari
# 8802    Movie                         Zodiac        David Fincher
# 8804    Movie                     Zombieland      Ruben Fleischer
# 8805    Movie                           Zoom         Peter Hewitt
# 8806    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
new_data.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5332 entries, 7 to 8806
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          5332 non-null   object
#  1   title         5332 non-null   object
#  2   director      5332 non-null   object
#  3   cast          5332 non-null   object
#  4   country       5332 non-null   object
#  5   release_year  5332 non-null   int64
#  6   rating        5332 non-null   object
#  7   duration      5332 non-null   object
#  8   listed_in     5332 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 416.6+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   release_year  8807 non-null   int64
#  6   rating        8803 non-null   object
#  7   duration      8804 non-null   object
#  8   listed_in     8807 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 619.4+ KB

# %%
new_data.describe()
# Out:
#        release_year
# count   5332.000000
# mean    2012.742123
# std        9.625831
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
import matplotlib.pyplot as plt

# %%
new_data.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'release_year',
#        'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
x = new_data['release_year']
y = new_data['rating']
plt.hist(x)
plt.show()

# %%
new1_data=data.fillna(method='pad')

# %%
new1_data
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show          Blood & Water  Kirsten Johnson
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans  Julien Leclercq
# 4     TV Show           Kota Factory  Julien Leclercq
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb    David Fincher
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...   South Africa
# ...

# %%
new1_data.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            1
# country         0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
new1_data.fillna(method='bfill')
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show          Blood & Water  Kirsten Johnson
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans  Julien Leclercq
# 4     TV Show           Kota Factory  Julien Leclercq
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb    David Fincher
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...   South Africa
# ...

# %%
new1_data.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            1
# country         0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
new1_data.dropna(how='any',axis=0)
# Out:
#          type                  title         director  \
# 1     TV Show          Blood & Water  Kirsten Johnson
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans  Julien Leclercq
# 4     TV Show           Kota Factory  Julien Leclercq
# 5     TV Show          Midnight Mass    Mike Flanagan
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb    David Fincher
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...   South Africa
# 3     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...   South Africa
# ...

# %%
new1_data.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            1
# country         0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
new_data.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'release_year',
#        'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
x = new_data['director']
y = new_data['country']
plt.plot(x,y)
plt.show()

# %%
x = new_data['release_year']
y = new_data['rating']
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ef85004ce0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ef85ccfb00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ef85c11fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ef85ccdfd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ef85ccd9d0>],
#  'means': []}

# %%
x = new_data['release_year']
y = new_data['rating']
plt.plot(x,color="green")

plt.title("Linear graph",fontsize=25,color="orange")
plt.ylabel('Y-Axis',color="green")
plt.xlabel('release_year',fontsize=20,color="red")
plt.ylim(1940,2030)
# Out:
# (1940.0, 2030.0)

# %%
x = new_data['release_year']
y = new_data['rating']
plt.plot(x,color="green")

plt.title("Linear graph",fontsize=25,color="orange")
plt.ylabel('Y-Axis',color="green")
plt.xlabel('release_year',fontsize=20,color="red")
plt.ylim(1940,2030)
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
x = new_data['release_year']
y = new_data['rating']
plt.plot(x,color="green")

plt.title("Linear graph",fontsize=25,color="orange")
plt.ylabel('Y-Axis',color="green")
plt.xlabel('release_year',fontsize=20,color="red")
plt.ylim(1950,2025)
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
x = new_data['release_year']
y = new_data['duration']
plt.scatter(x,y)
plt.ylim(90,100)
# Out:
# (90.0, 100.0)

# %%
new_data["rating"].unique()
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7',
#        'TV-G', 'TV-Y', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
new_data['rating'].replace({'TV-MA': 10,'TV-14': 5,'PG-13': 7,'PG': 6, 'R': 8,'TV-PG': 5,'G':1, 'TV-Y7': 2,'TV-G': 4, 'TV-Y': 1,
    'NC-17': 9,'NR': -1,'TV-Y7-FV': 3,'UR': -2},inplace=True)

# %%
new_data.rating
# Out:
# 7       10
# 8        5
# 9        7
# 12      10
# 24       5
#         ..
# 8801    10
# 8802     8
# 8804     8
# 8805     6
# 8806     5
# Name: rating, Length: 5332, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming 'data' is your DataFrame and 'rating' is a categorical column
label_encoder = LabelEncoder()
new_data['rating_encoded'] = label_encoder.fit_transform(new_data['rating'])

# Now 'rating_encoded' contains numeric representations of your categorical data

# %%
# Assuming 'data' is your DataFrame and 'rating' is a categorical column
data_encoded = pd.get_dummies(new_data, columns=['rating'])

# Now 'data_encoded' contains one-hot encoded columns for 'rating' and numerical data

# %%
X = new_data['rating']
Y = new_data['type']
#plt.bar(x,y)

# %%
new_data.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'release_year',
#        'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
X = pd.get_dummies(X)
X.head()
# Out:
#       -2     -1      1      2      3      4      5      6      7      8   \
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False   True  False  False  False
# 9   False  False  False  False  False  False  False  False   True  False
# 12  False  False  False  False  False  False  False  False  False  False
# 24  False  False  False  False  False  False   True  False  False  False
#
#        9      10
# 7   False   True
# 8   False  False
# 9   False  False
# 12  False   True
# 24  False  False

# %%
from sklearn.model_selection import train_test_split

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5332 entries, 7 to 8806
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          5332 non-null   object
#  1   title         5332 non-null   object
#  2   director      5332 non-null   object
#  3   cast          5332 non-null   object
#  4   country       5332 non-null   object
#  5   release_year  5332 non-null   int64
#  6   rating        5332 non-null   int64
#  7   duration      5332 non-null   object
#  8   listed_in     5332 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 416.6+ KB

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3,random_state=10)
X_train.shape, X_test.shape
# Out:
# ((3732,), (1600,))

# %%
Y_train.shape , Y_test.shape
# Out:
# ((3732,), (1600,))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)
clf_gini.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[178], line 2
#       1 clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)
# ----> 2 clf_gini.fit(X_train, Y_train)
#
# File c:\Users\jemin kheni\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\jemin kheni\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py:959, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
# ...

# %%
plt.figure(figsize=(12,8))

tree.plot_tree(clf_gini.fit(X_train, Y_train))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[177], line 3
#       1 plt.figure(figsize=(12,8))
# ----> 3 tree.plot_tree(clf_gini.fit(X_train, Y_train))
#
# File c:\Users\jemin kheni\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\jemin kheni\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_classes.py:959, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     928 @_fit_context(prefer_skip_nested_validation=True)
# ...

# %%
y_pred_gini = clf_gini.predict(X_test)

# %%
y_pred_train_gini = clf_gini.predict(X_train)

y_pred_train_gini
# Out:
# array(['Movie', 'Movie', 'Movie', ..., 'Movie', 'Movie', 'Movie'],
#       dtype=object)

# %%
print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(Y_test, y_pred_gini)))
#Accuracy Score for training set
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(Y_train, y_pred_train_gini)))
# Out:
# Model accuracy score with criterion gini index: 0.9781
# Training-set accuracy score: 0.9700

# %%
y_pred=clf_gini.predict(X_test)
conf_matrix =confusion_matrix(Y_test,y_pred)

# %%
conf_matrix
# Out:
# array([[1565,    0],
#        [  35,    0]], dtype=int64)

# %%
import warnings
warnings.filterwarnings('ignore')
A=classification_report(Y_test,y_pred)

# %%
print(f"classification_report:\n{A}")
# Out:
# classification_report:
#               precision    recall  f1-score   support
#
#        Movie       0.98      1.00      0.99      1565
#      TV Show       0.00      0.00      0.00        35
#
#     accuracy                           0.98      1600
#    macro avg       0.49      0.50      0.49      1600
# weighted avg       0.96      0.98      0.97      1600

# %%
from sklearn.naive_bayes import GaussianNB
classifier= GaussianNB()
classifier.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[171], line 3
#       1 from sklearn.naive_bayes import GaussianNB
#       2 classifier= GaussianNB()
# ----> 3 classifier.fit(X_train,Y_train)
#
# File c:\Users\jemin kheni\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\jemin kheni\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\naive_bayes.py:263, in GaussianNB.fit(self, X, y, sample_weight)
#     240 """Fit Gaussian Naive Bayes according to X, y.
# ...

# %%
Z_pred=classifier.predict(X_test)
Z_pred
# Out:
# array(['Movie', 'TV Show', 'Movie', ..., 'Movie', 'TV Show', 'TV Show'],
#       dtype='<U7')

# %%
Y_test
# Out:
# 6735    Movie
# 7412    Movie
# 2680    Movie
# 7901    Movie
# 6033    Movie
#         ...
# 4823    Movie
# 1039    Movie
# 7056    Movie
# 7509    Movie
# 5522    Movie
# Name: type, Length: 1600, dtype: object

# %%
classifier.score(X_test,Y_test)
# Out:
# 0.3225

# %%
import streamlit as st
import joblib

# %%
import pickle
import os
with open('clf_gini.pkl','wb')as fileWriteStream:
    pickle.dump(classifier,fileWriteStream)
    fileWriteStream.close()
